# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import seaborn as sns
import sys
sys.path.append("/home/jg2447/slayman/motif_inference/MOBI/scripts/")
from src import plt_func
from src import stats

# %%
enrichment_DNAinput = pd.read_csv("/home/jg2447/slayman/motif_inference/result/UnifyParaSearch/fly/enrichment/RankSPP_100.txt", sep="\t", index_col=0).loc[:,["250"]]
enrichment_DNAinput_c = pd.read_csv("/home/jg2447/slayman/motif_inference/result/UnifyParaSearch/fly/enrichment/RankCrowdness_100.txt", sep="\t", index_col=0).loc[:,["250"]]
enrichment_mockIP = pd.read_csv("/home/jg2447/slayman/motif_inference/result/mockIP/fly/enrichment/RankSPP_100.txt", sep="\t", index_col=0).loc[:,["250"]]
enrichment_mockIP_c = pd.read_csv("/home/jg2447/slayman/motif_inference/result/mockIP/fly/enrichment/RankCrowdness_100.txt", sep="\t", index_col=0).loc[:,["250"]]
inference_DNAinput = pd.read_csv("/home/jg2447/slayman/motif_inference/result/UnifyParaSearch/fly/tomtom_summary/DREME_RankSPP_100_top5.txt", sep="\t").loc[:,["TF", "accuracy"]]
inference_DNAinput_c = pd.read_csv("/home/jg2447/slayman/motif_inference/result/UnifyParaSearch/fly/tomtom_summary/DREME_RankCrowdness_100_top5.txt", sep="\t").loc[:,["TF", "accuracy"]]
inference_mockIP = pd.read_csv("/home/jg2447/slayman/motif_inference/result/mockIP/fly/tomtom_summary/DREME_RankSPP_100_top5.txt", sep="\t").loc[:,["TF", "accuracy"]]
inference_mockIP_c = pd.read_csv("/home/jg2447/slayman/motif_inference/result/mockIP/fly/tomtom_summary/DREME_RankCrowdness_100_top5.txt", sep="\t").loc[:,["TF", "accuracy"]]

enrichment_fly = enrichment_DNAinput
for df in [enrichment_mockIP, enrichment_DNAinput_c, enrichment_mockIP_c]:
    enrichment_fly = pd.merge(enrichment_fly, df, left_index=True, right_index=True)
inference_fly = inference_DNAinput
for df in [inference_mockIP, inference_DNAinput_c, inference_mockIP_c]:
    inference_fly = pd.merge(inference_fly, df, left_on="TF", right_on="TF")
inference_fly = inference_fly.set_index("TF")

fly_data = pd.merge(enrichment_fly, inference_fly, left_index=True, right_index=True)
fly_data.columns = ["enrichment_DNAinput", "enrichment_mockIP", "enrichment_DNAinput_c", "enrichment_mockIP_c", "inference_DNAinput", "inference_mockIP", "inference_DNAinput_c", "inference_mockIP_c"]

# %%
enrichment_DNAinput = pd.read_csv("/home/jg2447/slayman/motif_inference/result/UnifyParaSearch/worm/enrichment/RankSPP_100.txt", sep="\t", index_col=0).loc[:,["250"]]
enrichment_DNAinput_c = pd.read_csv("/home/jg2447/slayman/motif_inference/result/UnifyParaSearch/worm/enrichment/RankCrowdness_100.txt", sep="\t", index_col=0).loc[:,["250"]]
enrichment_mockIP = pd.read_csv("/home/jg2447/slayman/motif_inference/result/mockIP/worm/enrichment/RankSPP_100.txt", sep="\t", index_col=0).loc[:,["250"]]
enrichment_mockIP_c = pd.read_csv("/home/jg2447/slayman/motif_inference/result/mockIP/worm/enrichment/RankCrowdness_100.txt", sep="\t", index_col=0).loc[:,["250"]]
inference_DNAinput = pd.read_csv("/home/jg2447/slayman/motif_inference/result/UnifyParaSearch/worm/tomtom_summary/DREME_RankSPP_100_top5.txt", sep="\t").loc[:,["TF", "accuracy"]]
inference_DNAinput_c = pd.read_csv("/home/jg2447/slayman/motif_inference/result/UnifyParaSearch/worm/tomtom_summary/DREME_RankCrowdness_100_top5.txt", sep="\t").loc[:,["TF", "accuracy"]]
inference_mockIP = pd.read_csv("/home/jg2447/slayman/motif_inference/result/mockIP/worm/tomtom_summary/DREME_RankSPP_100_top5.txt", sep="\t").loc[:,["TF", "accuracy"]]
inference_mockIP_c = pd.read_csv("/home/jg2447/slayman/motif_inference/result/mockIP/worm/tomtom_summary/DREME_RankCrowdness_100_top5.txt", sep="\t").loc[:,["TF", "accuracy"]]

enrichment_worm = enrichment_DNAinput
for df in [enrichment_mockIP, enrichment_DNAinput_c, enrichment_mockIP_c]:
    enrichment_worm = pd.merge(enrichment_worm, df, left_index=True, right_index=True)
inference_worm = inference_DNAinput
for df in [inference_mockIP, inference_DNAinput_c, inference_mockIP_c]:
    inference_worm = pd.merge(inference_worm, df, left_on="TF", right_on="TF")
inference_worm = inference_worm.set_index("TF")

worm_data = pd.merge(enrichment_worm, inference_worm, left_index=True, right_index=True)
worm_data.columns = ["enrichment_DNAinput", "enrichment_mockIP", "enrichment_DNAinput_c", "enrichment_mockIP_c", "inference_DNAinput", "inference_mockIP", "inference_DNAinput_c", "inference_mockIP_c"]

# %%
figsize = (3, 2)
panel_number_fs = 8
x_tick_label_fs = 5
y_tick_label_fs = 5
x_label_fs = 5
y_label_fs = 5
title_fs = 6
legend_fs = 6

colors = ["#8ff098", "#8ba898"]

sns.set_context("paper")

fig, axs = plt.subplots(
    nrows=2, ncols=2, 
    sharex=False, sharey=False,
    gridspec_kw={'hspace': 0.4, "height_ratios":[1, 1]},
    figsize=figsize, dpi=300)

# A
ax = axs[0, 0]
ax.barh([3,2,1,0], fly_data.mean().values[:4])
ax.set_ylim([-0.75,3.75])
ax.yaxis.set_ticks([0,1,2,3])
ax.yaxis.set_ticklabels(["MockIP_C-score","DNAinput_C-score","MockIP_SPP","DNAinput_SPP"])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines["left"].set_linewidth(0.5)
ax.spines["bottom"].set_linewidth(0.5)
ax.xaxis.set_ticks([0,0.1,0.2])
ax.get_yaxis().set_tick_params(size=0, pad=2, labelsize=x_tick_label_fs)   
ax.get_xaxis().set_tick_params(size=2.5, width=0.5, pad=1, labelsize=y_tick_label_fs)
ax.set_xlabel("Motif enrichment", fontsize=x_label_fs, labelpad=0.3)
ax.set_title("Fly", fontsize=title_fs, pad=0.3)

ax = axs[1, 0]
ax.barh([3,2,1,0], fly_data.mean().values[4:])
ax.set_ylim([-0.75,3.75])
ax.yaxis.set_ticks([0,1,2,3])
ax.yaxis.set_ticklabels(["MockIP_C-score","DNAinput_C-score","MockIP_SPP","DNAinput_SPP"])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines["left"].set_linewidth(0.5)
ax.spines["bottom"].set_linewidth(0.5)
ax.xaxis.set_ticks([0,0.25,0.5,0.75])
ax.get_yaxis().set_tick_params(size=0, pad=2, labelsize=x_tick_label_fs)   
ax.get_xaxis().set_tick_params(size=2.5, width=0.5, pad=1, labelsize=y_tick_label_fs)
ax.set_xlabel("Motif inference accuracy", fontsize=x_label_fs, labelpad=0.3)

#B
ax = axs[0, 1]
ax.barh([3,2,1,0], worm_data.mean().values[:4])
ax.set_ylim([-0.75,3.75])
ax.yaxis.set_ticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines["left"].set_linewidth(0.5)
ax.spines["bottom"].set_linewidth(0.5)
ax.xaxis.set_ticks([0,0.1,0.2])
ax.get_yaxis().set_tick_params(size=0, pad=2, labelsize=x_tick_label_fs)   
ax.get_xaxis().set_tick_params(size=2.5, width=0.5, pad=1, labelsize=y_tick_label_fs)
ax.set_xlabel("Motif enrichment", fontsize=x_label_fs, labelpad=0.3)
ax.set_title("Worm", fontsize=title_fs, pad=0.3)

ax = axs[1, 1]
ax.barh([3,2,1,0], worm_data.mean().values[4:])
ax.set_ylim([-0.75,3.75])
ax.yaxis.set_ticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines["left"].set_linewidth(0.5)
ax.spines["bottom"].set_linewidth(0.5)
ax.xaxis.set_ticks([0,0.25,0.5,0.75])
ax.get_yaxis().set_tick_params(size=0, pad=2, labelsize=x_tick_label_fs)   
ax.get_xaxis().set_tick_params(size=2.5, width=0.5, pad=1, labelsize=y_tick_label_fs)
ax.set_xlabel("Motif inference accuracy", fontsize=x_label_fs, labelpad=0.3)

#plt.show()
plt.savefig("./figS3.pdf", dpi="figure", bbox_inches="tight")
